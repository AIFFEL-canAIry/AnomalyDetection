# %%
import os
from glob import glob
import shutil
from tqdm import tqdm

# %%
EXTENSION_CSV = ".csv"
EXTENSION_JSON = ".json"
EXTENSION_JPG = ".jpg"
EXTENSION_TXT = ".txt"

# %% [markdown]
# # 원본 데이터셋 확인

# %%
PATH_DATASET = "/content/drive/MyDrive/canAiry/data/02_2nd-dataset/01-1_SS-mof"

PATH_CSV_TRAIN = PATH_DATASET + "/00_csv/train/"
PATH_CSV_VAL = PATH_DATASET + "/00_csv/val/"
PATH_CSV_TEST = PATH_DATASET + "/00_csv/test/"

PATH_JSON_TRAIN = PATH_DATASET + "/01_label/train/"
PATH_JSON_VAL = PATH_DATASET + "/01_label/val/"
PATH_JSON_TEST = PATH_DATASET + "/01_label/test/"

# %%
csv_train = glob(PATH_CSV_TRAIN+'*'+EXTENSION_CSV)
csv_val = glob(PATH_CSV_VAL+'*'+EXTENSION_CSV)
csv_test = glob(PATH_CSV_TEST+'*'+EXTENSION_CSV)
csv_size = [len(csv_train), len(csv_val), len(csv_test)]
csv_size
# Out:
# [960, 120, 120]

# %%
json_train = glob(PATH_JSON_TRAIN+'*'+EXTENSION_JSON)
json_val = glob(PATH_JSON_VAL+'*'+EXTENSION_JSON)
json_test = glob(PATH_JSON_TEST+'*'+EXTENSION_JSON)
json_size = [len(json_train), len(json_val), len(json_test)]
json_size
# Out:
# [960, 120, 120]

# %% [markdown]
# # YOLO 데이터셋 확인

# %%
PATH_DATASET_YOLO = "/content/drive/MyDrive/object_detection/datasets/canAIry/EP-motor"

PATH_TRAIN_IMAGE = PATH_DATASET_YOLO + "/train/images/"
PATH_VAL_IMAGE = PATH_DATASET_YOLO + "/val/images/"
PATH_TEST_IMAGE = PATH_DATASET_YOLO + "/test/images/"

PATH_TRAIN_LABEL = PATH_DATASET_YOLO + "/train/labels/"
PATH_VAL_LABEL = PATH_DATASET_YOLO + "/val/labels/"
PATH_TEST_LABEL = PATH_DATASET_YOLO + "/test/labels/"

# %%
image_train = glob(PATH_TRAIN_IMAGE+'*'+EXTENSION_JPG)
image_val = glob(PATH_VAL_IMAGE+'*'+EXTENSION_JPG)
image_test = glob(PATH_TEST_IMAGE+'*'+EXTENSION_JPG)
image_size = [len(image_train), len(image_val), len(image_test)]
image_size
# Out:
# [960, 120, 120]

# %%
label_train = glob(PATH_TRAIN_LABEL+'*'+EXTENSION_TXT)
label_val = glob(PATH_VAL_LABEL+'*'+EXTENSION_TXT)
label_test = glob(PATH_TEST_LABEL+'*'+EXTENSION_TXT)
label_size = [len(label_train), len(label_val), len(label_test)]
label_size
# Out:
# [960, 120, 120]
