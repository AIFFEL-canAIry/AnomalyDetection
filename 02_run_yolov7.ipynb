# %%
import os
from glob import glob
from tqdm import tqdm
import json
from PIL import Image
from IPython.display import Image as Img
from IPython.display import display

# %% [markdown]
# # 학습

# %%
os.chdir("/content/drive/MyDrive/object_detection")

# %%
# %%capture
# !pip install wandb

# %%
# !python yolov7/train.py --img-size 640 640 --batch-size 16 --epochs 300 --data datasets/canAIry_EP.yaml --cfg yolov7/cfg/training/yolov7.yaml --weight "" --project results/train/YOLOv7 --name EP
# Out:
# YOLOR 🚀 2022-9-17 torch 1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='yolov7/cfg/training/yolov7.yaml', data='datasets/canAIry_EP.yaml', device='', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='./yolov7/data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='EP', noautoanchor=False, nosave=False, notest=False, project='results/train/YOLOv7', quad=False, rect=False, resume=False, save_dir='results/train/YOLOv7/EP', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, v5_metric=False, weights='', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir results/train/YOLOv7', view at http://localhost:6006/
# ...

# %% [markdown]
# # 추론

# %%
os.chdir("/content/drive/MyDrive/object_detection/yolov7")

# %%
# !python detect.py --weights ../results/train/YOLOv7/EP/weights/best.pt --img 640 --conf 0.1 --source ../datasets/canAIry/EP-circuit/test/images --project ../results/detect/YOLOv7 --name EP-circuit
# !python detect.py --weights ../results/train/YOLOv7/EP/weights/best.pt --img 640 --conf 0.1 --source ../datasets/canAIry/EP-motor/test/images --project ../results/detect/YOLOv7 --name EP-motor

# %%
# !python detect.py --weights ../results/train/YOLOv7/SS/weights/best.pt --img 640 --conf 0.1 --source ../datasets/canAIry/SS-mof/test/images --project ../results/detect/YOLOv7 --name SS-mof
# !python detect.py --weights ../results/train/YOLOv7/SS/weights/best.pt --img 640 --conf 0.1 --source ../datasets/canAIry/SS-PT/test/images --project ../results/detect/YOLOv7 --name SS-PT

# %%
# !python detect.py --weights ../results/train/YOLOv7/IC/weights/best.pt --img 640 --conf 0.1 --source ../datasets/canAIry/IC-boiler/test/images --project ../results/detect/YOLOv7 --name IC-boiler
# !python detect.py --weights ../results/train/YOLOv7/IC/weights/best.pt --img 640 --conf 0.1 --source ../datasets/canAIry/IC-pump/test/images --project ../results/detect/YOLOv7 --name IC-pump

# %%
# !python detect.py --weights ../results/train/YOLOv7/TR/weights/best.pt --img 640 --conf 0.1 --source ../datasets/canAIry/TR-bearing/test/images --project ../results/detect/YOLOv7 --name TR-bearing
# !python detect.py --weights ../results/train/YOLOv7/TR/weights/best.pt --img 640 --conf 0.1 --source ../datasets/canAIry/TR-gearbox/test/images --project ../results/detect/YOLOv7 --name TR-gearbox
