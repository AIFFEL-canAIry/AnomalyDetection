# %%
import os
from glob import glob
from tqdm import tqdm
import json
from PIL import Image
from IPython.display import Image as Img
from IPython.display import display
os.chdir("/content/drive/MyDrive/object_detection/yolov5")

# %%
CLASS_NAME = "TR-bearing"
PATH_WEIGHTS = "../results/train/YOLOv5/TR/weights/best.pt"
PATH_PROJECT = "../results/detect/YOLOv5"
PATH_SOURCE = "../datasets/canAIry/"+CLASS_NAME+"/test/images"
PATH_LABEL = "../datasets/canAIry/"+CLASS_NAME+"/test/labels"

# %%
# !python detect.py --img 640 --conf 0.1 --weights {PATH_WEIGHTS} --source {PATH_SOURCE} --save-crop --project {PATH_PROJECT} --name {CLASS_NAME} --label-dir {PATH_LABEL}
# Out:
# detect: weights=['../results/train/YOLOv5/TR/weights/best.pt'], source=../datasets/canAIry/TR-bearing/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../results/detect/YOLOv5, name=TR-bearing, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, label_dir=../datasets/canAIry/TR-bearing/test/labels
# YOLOv5 🚀 v6.2-123-g5e1a955 Python-3.7.14 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 212 layers, 20865057 parameters, 0 gradients
#
# 114/123 (92.68%)
#
# Speed: 0.9ms pre-process, 280.7ms inference, 0.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to ../results/detect/YOLOv5/TR-bearing2

# %% [markdown]
# # Visualization

# %%
def display_result(list_result, path_label):
  for result in list_result:
    test_name = os.path.splitext(result.split('/')[-1])[0]
    with open(path_label+'/'+test_name+'.json', "r") as f:
      dict_label = json.load(f)
      for obj in dict_label["annotations"]:
        class_name = obj["class"]
        status = "normal"
        if obj["attributes"]["status"] != "normal":
          status = obj["attributes"]["status"]
      display(Img(filename=result))
      print(f"[{class_name}] {status}\n")

# %%
PATH_LABEL = "/content/drive/MyDrive/canAiry/data/02_2nd-dataset/04-1_TR-bearing/01_label/test"
PATH_RESULT = PATH_PROJECT+'/'+CLASS_NAME
results = glob(PATH_RESULT + '/*.jpg')

# %%
display_result(results, PATH_LABEL)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## GIF 생성

# %%
def generate_gif():
  img_list = [PATH_PROJECT+'/'+CLASS_NAME+'/'+x for x in os.listdir(PATH_PROJECT+'/'+CLASS_NAME)[1:]]
  images = [Image.open(x) for x in img_list]
  # loop 반복 횟수
  # duration 프레임 전환 속도 (500 = 0.5초)
  img = images[0]
  img.save(PATH_PROJECT+'/GIF/'+CLASS_NAME+'.gif', save_all=True, append_images=images[1:],loop=1, duration=100)
  return

# %%
generate_gif()
